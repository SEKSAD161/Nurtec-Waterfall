# %%
import subprocess, sys
try:
    import snowflake.connector
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "snowflake-connector-python", "--quiet"])
    import snowflake.connector
print("connector version:", snowflake.connector.__version__)
print("python:", sys.version)
